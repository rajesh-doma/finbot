# %% [markdown]
# <a href="https://colab.research.google.com/github/rajesh-doma/finbot/blob/main/01_document_parsing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rajesh")
# Out:
# rajesh
